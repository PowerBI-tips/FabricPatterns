# %% [markdown]
# # Semantic Link Labs
#
# Project created and maintained by [Michael Kovalsky](https://www.linkedin.com/in/michaelkovalsky/) on the Fabric CAT team. Follow his blog [ElegantBI](https://www.elegantbi.com/) for all the rich content he is producing around Semantic Link Labs and other tools for developers.
#
# [Semantic Link Labs on Github](https://github.com/microsoft/semantic-link-labs)
#
# Over +300 functions developed to assist users working with Power BI, Fabric and APIs
#
# [Docs for Semantic Link Labs](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.html)
#
# Labs is an extension on the core capabilities of [Semantic Link](https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-overview)
#
# ## Notebook Requirements
#
# For this notebook to run, you will need a fabric capacity running on a standard session. Some commands will work

# %% [markdown]
# ## Setup of notebook
#
# Install the semantic link labs using pip magic command.
#
# > Note: Using pip command will only work with a standard session and will not work with a high concurrency session

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, 993971ea-1635-409b-bbf1-489dd1e2ef47, 8, Finished, Available, Finished)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.8.3-py3-none-any.whl.metadata (16 kB)
# Collecting semantic-link-sempy>=0.8.0 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.8.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (3.1.1)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting azure.mgmt.resource (from semantic-link-labs)
#   Downloading azure_mgmt_resource-23.1.1-py3-none-any.whl.metadata (37 kB)
# Collecting jsonpath-ng (from semantic-link-labs)
#   Downloading jsonpath-ng-1.7.0.tar.gz (37 kB)
# done
# done
# done
# done
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.8.0->semantic-link-labs) (4.65.0)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure.mgmt.resource->semantic-link-labs) (0.6.1)
# Collecting azure-common>=1.1 (from azure.mgmt.resource->semantic-link-labs)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-mgmt-core>=1.3.2 (from azure.mgmt.resource->semantic-link-labs)
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath-ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (8.1.2)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.0.0)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.25.0)
# Requirement already satisfied: requests>=2.25.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (2.31.0)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyspark in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-mgmt-core>=1.3.2->azure.mgmt.resource->semantic-link-labs) (1.30.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.8.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.10)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.8.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (42.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyarrow>=12.0.1->semantic-link-sempy>=0.8.0->semantic-link-labs) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.0->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.8.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark->powerbiclient->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.26.2->azure-mgmt-core>=1.3.2->azure.mgmt.resource->semantic-link-labs) (4.9.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.8.0->semantic-link-labs) (2.21)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.5)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.2)
# Downloading semantic_link_labs-0.8.3-py3-none-any.whl (580 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 580.3/580.3 kB 10.8 MB/s eta 0:00:00 0:00:01
# Downloading semantic_link_sempy-0.8.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 65.9 MB/s eta 0:00:00a 0:00:01
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 14.0 MB/s eta 0:00:00
# Downloading azure_mgmt_resource-23.1.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 207.1 MB/s eta 0:00:00
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Building wheels for collected packages: jsonpath-ng
# done
#   Created wheel for jsonpath-ng: filename=jsonpath_ng-1.7.0-py3-none-any.whl size=30099 sha256=76fd4730d135173fb3467147f4f7ae1a1116bbe7b401370fe948bd5cf08dfec9
#   Stored in directory: /home/trusted-service-user/.cache/pip/wheels/6b/47/94/d8ae7a868e6642221f5caa53d6aedce4ff138c76c9f031a3da
# Successfully built jsonpath-ng
# Installing collected packages: polib, azure-common, jsonpath-ng, anytree, azure-mgmt-core, semantic-link-sempy, azure.mgmt.resource, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.7.7
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-cd430378-d81c-467d-91d6-09b1be765de6
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# Successfully installed anytree-2.12.1 azure-common-1.1.28 azure-mgmt-core-1.4.0 azure.mgmt.resource-23.1.1 jsonpath-ng-1.7.0 polib-1.2.0 semantic-link-labs-0.8.3 semantic-link-sempy-0.8.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
import sempy_labs as labs
import sempy_labs.report as rep
# Out:
# StatementMeta(, 993971ea-1635-409b-bbf1-489dd1e2ef47, 10, Finished, Available, Finished)

# %% [markdown]
# ## Listing items from Fabric

# %% [markdown]
# Shows the capacities and their properties
#
# [list capacities](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.html#sempy_labs.list_capacities)

# %%
labs.list_capacities()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 16, Finished, Available, Finished)
#                                      Id  \
# 0  6448f64c-8ec8-4008-90cf-edd1e9811b6c
# 1  2c60ca79-d408-47a4-ace8-8a3feb9e6bf4
# 2  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 3  d57a3a51-cae1-4c2b-93b2-a37960d13615
#
#                                    Display Name  Sku            Region  \
# 0  Trial-mike-powerbi-tips-05-23-2023-18-10-UTC  FT1  North Central US
# 1                                      embedded   A1  North Central US
# 2                             demolearnfabric02   F2  North Central US
# 3                   Premium Per User - Reserved  PP3  North Central US
#
#     State                                             Admins
# 0  Active                                [mike@powerbi.tips]
# 1  Active  [mike@powerbi.tips, seth@powerbi.tips, 1c4acb6...
# 2  Active  [mike@powerbi.tips, ryan@powerbi.tips, dan.mei...
# 3  Active                                                 []

# %% [markdown]
# A list of all the users of a workspace and their roles.
#
# [list_workspace_users](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.html#sempy_labs.list_workspace_users)

# %%
labs.list_workspace_users()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 17, Finished, Available, Finished)
#       User Name              Email Address    Role  Type  \
# 0    Mike Carlo          mike@powerbi.tips   Admin  User
# 1  Dan Meissner  dan.meissner@powerbi.tips  Member  User
#
#                                 User ID
# 0  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 1  00c7050a-4931-49d6-84c5-0f3dabcf78c6

# %%
labs.list_workspace_users('Demo - Learn Fabric')
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 18, Finished, Available, Finished)
#                 User Name              Email Address   Role   Type  \
# 0            Learn Fabric                       None  Admin  Group
# 1              Mike Carlo          mike@powerbi.tips  Admin   User
# 2  Learn Fabric Test User  learn.fabric@powerbi.tips  Admin   User
#
#                                 User ID
# 0  ec61d042-2902-48ce-94ef-3dd8456d44c4
# 1  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 2  21468032-c727-4430-ad8e-430a64e6f6f2

# %%
users = labs.list_workspace_users('Demo - Learn Fabric')

display(users)
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 21, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 12cd89c5-f316-4f52-a502-8966f26cf37c)

# %%
users[users['Type'] == 'Group']
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 23, Finished, Available, Finished)
#       User Name Email Address   Role   Type  \
# 0  Learn Fabric          None  Admin  Group
#
#                                 User ID
# 0  ec61d042-2902-48ce-94ef-3dd8456d44c4

# %% [markdown]
# Shows a list of all dataflows which exist within a workspace.
#
# [list_dataflows](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.html#sempy_labs.list_dataflows)

# %%
labs.list_dataflows('Demo - Learn Fabric')
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 34, Finished, Available, Finished)
#                             Dataflow Id                 Dataflow Name  \
# 0  00205554-576c-42b0-8386-d948106a160d  Load Finacial Data From File
# 1  0314631d-9aa8-4a2e-a88a-6d03cb933377     Baseball Data From Github
#
#                Configured By Users  Generation
# 0  learn.fabric@powerbi.tips    []           0
# 1          mike@powerbi.tips    []           0

# %% [markdown]
# Shows a list of deployment pipelines the user can access
#
# [list_deployment_pipelines](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.html#sempy_labs.list_deployment_pipelines)

# %%
labs.list_deployment_pipelines()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 40, Finished, Available, Finished)
#                  Deployment Pipeline Id Deployment Pipeline Name  \
# 0  5ad1a100-61be-4d22-8a90-30739f9ba108          CI / CD Example
# 1  b7219fe6-fc3d-466b-a903-2b5dc67dfbca          Deploy Anywhere
#
#                                          Description
# 0  Sample Dev, Test, to Prod workspaces for testi...
# 1

# %% [markdown]
# # Sub Modules
#
# A collection of functions that are handling specific areas. These are intended for a specific user or a user who performs specific functions. Such as an Admin or data modeler manipulating semantic models.

# %% [markdown]
# ## Admin

# %% [markdown]
# Lists all domains of the tenant
#
# [list_domains](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.admin.html#sempy_labs.admin.list_domains)

# %%
labs.admin.list_domains()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 15, Finished, Available, Finished)
#                               Domain ID        Domain Name  \
# 0  4b01f3be-0a19-41e1-9857-821dbb0179c5     Public Content
# 1  d25bac07-0a9b-4961-9de1-8c3f115f830b        Azure A Sku
# 2  8fe4ceff-a1e1-493f-b7e5-47f45f7a8726    Fabric Capacity
# 3  f8cad61f-4316-4669-ad21-47943b00f851            HR Team
# 4  50165376-c35b-4c9e-9a75-60157af6b5d3  Public Sub-Domain
# 5  9dbedd99-838f-4735-abfe-887a2224f379            Mini HR
# 6  ed26fa9c-ce0c-45e8-a41b-f49347a2ff27         AM Session
# 7  cbd6943c-825e-422b-a4c6-b0a257289c20         PM session
#
#                                          Description  \
# 0  Collection of workspaces that serve public act...
# 1                      Workspaces using Azure A1 sku
# 2                   Workspaces that are using Fabric
# 3
# 4
# 5
# 6
# 7
#
#                        Parent Domain ID Contributors Scope
# 0                                  None          AllTenant
# 1                                  None         AdminsOnly
# 2                                  None          AllTenant
# 3                                  None         AdminsOnly
# 4  4b01f3be-0a19-41e1-9857-821dbb0179c5          AllTenant
# 5  f8cad61f-4316-4669-ad21-47943b00f851          AllTenant
# 6                                  None          AllTenant
# 7                                  None          AllTenant

# %% [markdown]
# Shows a list of active Fabric and PowerBI items
#
# [list_items](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.admin.html#sempy_labs.admin.list_items)

# %%
labs.admin.list_items()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 48, Finished, Available, Finished)
#                                   Item Id                   Item Name  \
# 0    a62add50-3aa0-47b1-92f5-738eb03a7f0f                 Dev_Lake_01
# 1    44811cae-2fd7-4292-bd3f-a25b0bbda9ae                TheGreatLake
# 2    304dd361-58fa-4c68-801d-3c7627bfcd36  DataflowsStagingLakehouse1
# 3    4850030f-57dd-4e9a-ad4e-b313ac6d5451          WorldWideImporters
# 4    b79ce1e6-fabe-4642-b68a-c8f47a4b08cc               NYC_Taxi_Load
# ..                                    ...                         ...
# 781  9aaf3f90-7f27-4a81-9224-51477d30c51c                        None
# 782  6f2b9fb2-9cc3-4d13-bd41-0325864dcc86                        None
# 783  38aedd79-9688-4b07-ba0e-d8f6b7608639                        None
# 784  0ec7f381-34ae-4f2e-b9b2-0e02f908cd3e                        None
# 785  e0783a1d-0f37-47ab-b9b7-6a5dc24d3f5f                        None
#
#              Type                      Description   State  \
# 0       Lakehouse                             None  Active
# 1       Lakehouse  Learn fabric lakehouse for data  Active
# 2       Lakehouse                             None  Active
# 3       Lakehouse                             None  Active
# 4    DataPipeline                             None  Active
# ..            ...                              ...     ...
# 781      Dataflow                             None  Active
# 782      Dataflow                             None  Active
# 783      Dataflow                             None  Active
# 784      Dataflow                             None  Active
# 785      Dataflow                             None  Active
#
#                Last Updated Date                  Creator Principal Id  \
# 0    2023-12-14T20:23:28.6034343  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 1    2024-10-02T14:11:32.1800211  70274950-b208-4db6-9b30-75c74be2bd48
# 2    2024-10-02T14:11:35.4769262  21468032-c727-4430-ad8e-430a64e6f6f2
# 3    2024-10-02T14:11:39.0083637  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 4    2024-10-02T14:11:42.8363077  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# ..                           ...                                   ...
# 781          2024-08-27T16:31:33  00c7050a-4931-49d6-84c5-0f3dabcf78c6
# 782      2024-09-13T17:37:02.427  6d6283de-0357-45dc-9a4f-a41379ae84a1
# 783       2024-09-13T17:37:04.32  6d6283de-0357-45dc-9a4f-a41379ae84a1
# 784      2024-09-18T18:34:04.577  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 785       2024-10-01T19:12:40.99  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
#
#     Creator Principal Display Name Creator Principal Type  \
# 0                       Mike Carlo                   User
# 1                     Tommy Puglia                   User
# 2           Learn Fabric Test User                   User
# 3                       Mike Carlo                   User
# 4                       Mike Carlo                   User
# ..                             ...                    ...
# 781                   Dan Meissner                   User
# 782             Nathan Wagenknecht                   User
# 783             Nathan Wagenknecht                   User
# 784                     Mike Carlo                   User
# 785                     Mike Carlo                   User
#
#     Creator User Principal Name                          Workspace Id  \
# 0             mike@powerbi.tips  c7ef6343-ff3a-4d16-86b3-ed3ee7bc7cd1
# 1          tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 2     learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 3             mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 4             mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# ..                          ...                                   ...
# 781   dan.meissner@powerbi.tips  ee6d73bf-32ed-46a9-8afe-04accfecb757
# 782         nathan@powerbi.tips  98b71d9e-1a04-4510-b94c-6505a62a0ba3
# 783         nathan@powerbi.tips  98b71d9e-1a04-4510-b94c-6505a62a0ba3
# 784           mike@powerbi.tips  2698aa2d-0c07-4fae-a6b2-287389003f03
# 785           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
#
#                               Capacity Id
# 0    18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 1    18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 2    18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 3    18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 4    18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# ..                                    ...
# 781  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 782  14c45eae-14a5-455b-b1a5-f21669d80186
# 783  14c45eae-14a5-455b-b1a5-f21669d80186
# 784  6448f64c-8ec8-4008-90cf-edd1e9811b6c
# 785  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
#
# [786 rows x 12 columns]

# %%
labs.admin.list_items(workspace='Demo - Learn Fabric')
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 50, Finished, Available, Finished)
#                                  Item Id                     Item Name  \
# 0   44811cae-2fd7-4292-bd3f-a25b0bbda9ae                  TheGreatLake
# 1   304dd361-58fa-4c68-801d-3c7627bfcd36    DataflowsStagingLakehouse1
# 2   4850030f-57dd-4e9a-ad4e-b313ac6d5451            WorldWideImporters
# 3   b79ce1e6-fabe-4642-b68a-c8f47a4b08cc                 NYC_Taxi_Load
# 4   b733be19-aed3-4eea-a3fa-f3c0e620d932                      NYC_Taxi
# 5   f33559f1-8812-4154-a874-0c025101c80f       Sample Loading Patterns
# 6   2d3a035f-5703-4d3d-9559-8beb641af530        Load Batting Tables DF
# 7   e3c8aaf8-df8e-41ac-a745-1b2dc2678a9a        Intro to Data Wrangler
# 8   1ba52d50-8a2f-4211-8321-0036b5668129       Sample Writing Patterns
# 9   3788119a-1eac-42ff-a918-e8623e409dba                     ShortCuts
# 10  268cef9d-7e99-4018-b3f5-69ea9256804c                  TheGreatLake
# 11  5eb534f9-43c4-4f9a-a65a-237c8d81087b    DataflowsStagingLakehouse1
# 12  5795c746-618e-4ee8-9135-e4c1916d361b            WorldWideImporters
# 13  10fdbb03-e4da-4ec5-adc0-2485c4413ed7                      NYC_Taxi
# 14  d170adec-32ef-4b3d-bcba-aa61404e0f7a                     ShortCuts
# 15  cff0f29f-c4a4-49b0-8f33-5e36761c3134    Paginated - HR Year Decade
# 16  ed1fd441-a850-4105-86bd-abfa1a3497ae         Auto Generated Report
# 17  8dbde1be-a6fc-4a10-905e-f2211c45bad7            Runs by Birth Year
# 18  e49591c8-4f4a-4c0c-838b-9a62165f0816           NYC Taxi AutoReport
# 19  62320506-bd9b-4c66-a7aa-8bb8f324b546                  TheGreatLake
# 20  0eb91f22-f726-40e1-b3e5-21f0018926bb    DataflowsStagingLakehouse1
# 21  fb90dd56-639e-4da8-9eb9-04125b74ba07               Batting Dataset
# 22  030e8e56-3d5e-4c6a-824d-042293d340cd            WorldWideImporters
# 23  2e76574a-4e24-47a6-af2b-6687c64c43f6                      NYC_Taxi
# 24  2582cd67-8ad9-4110-b177-b0e0d4e6cfe7                   Taxi Data 2
# 25  c13bb7d4-66a0-4d0b-8df5-81f089687b82                     ShortCuts
# 26  a70a26ca-e8a0-457b-9b88-636d21ac5174                          None
# 27  3664e98f-3f3e-445e-9052-ade237eef124                          None
# 28  00205554-576c-42b0-8386-d948106a160d  Load Finacial Data From File
# 29  0314631d-9aa8-4a2e-a88a-6d03cb933377     Baseball Data From Github
# 30  521c7048-517c-439a-86df-6ec5e8b65e19                          None
# 31  2b6e46b6-a276-4b86-924b-934e6cb2c75a                          None
# 32  e0783a1d-0f37-47ab-b9b7-6a5dc24d3f5f                          None
#
#              Type                      Description   State  \
# 0       Lakehouse  Learn fabric lakehouse for data  Active
# 1       Lakehouse                             None  Active
# 2       Lakehouse                             None  Active
# 3    DataPipeline                             None  Active
# 4       Lakehouse                             None  Active
# 5        Notebook                     New notebook  Active
# 6        Notebook                     New notebook  Active
# 7        Notebook                     New notebook  Active
# 8        Notebook                     New notebook  Active
# 9       Lakehouse                             None  Active
# 10    SQLEndpoint                             None  Active
# 11    SQLEndpoint                             None  Active
# 12    SQLEndpoint                             None  Active
# 13    SQLEndpoint                             None  Active
# 14    SQLEndpoint                             None  Active
# 15         Report                             None  Active
# 16         Report                             None  Active
# 17         Report                             None  Active
# 18         Report                             None  Active
# 19  SemanticModel                             None  Active
# 20  SemanticModel                             None  Active
# 21  SemanticModel                             None  Active
# 22  SemanticModel                             None  Active
# 23  SemanticModel                             None  Active
# 24  SemanticModel                             None  Active
# 25  SemanticModel                             None  Active
# 26       Dataflow                             None  Active
# 27       Dataflow                             None  Active
# 28       Dataflow                             None  Active
# 29       Dataflow                             None  Active
# 30       Dataflow                             None  Active
# 31       Dataflow                             None  Active
# 32       Dataflow                             None  Active
#
#               Last Updated Date                  Creator Principal Id  \
# 0   2024-10-02T14:11:32.1800211  70274950-b208-4db6-9b30-75c74be2bd48
# 1   2024-10-02T14:11:35.4769262  21468032-c727-4430-ad8e-430a64e6f6f2
# 2   2024-10-02T14:11:39.0083637  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 3   2024-10-02T14:11:42.8363077  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 4   2024-10-02T14:11:46.1644512  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 5   2024-10-16T03:04:13.2192935  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 6   2024-10-02T14:11:53.2894741  70274950-b208-4db6-9b30-75c74be2bd48
# 7   2024-10-16T03:03:55.1567474  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 8   2024-10-16T03:04:31.8756026  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 9   2024-10-02T14:12:03.5863982  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 10       2024-10-10T13:00:46.69  70274950-b208-4db6-9b30-75c74be2bd48
# 11      2024-10-02T14:11:27.553  21468032-c727-4430-ad8e-430a64e6f6f2
# 12      2024-10-02T14:11:27.583  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 13       2024-10-02T14:11:27.56  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 14       2024-10-02T14:11:27.57  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 15          0001-01-01T00:00:00  70274950-b208-4db6-9b30-75c74be2bd48
# 16      2023-11-16T18:48:59.237  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 17          0001-01-01T00:00:00  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 18          0001-01-01T00:00:00  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 19      2023-07-06T17:38:54.017  70274950-b208-4db6-9b30-75c74be2bd48
# 20      2023-07-10T17:47:15.667  21468032-c727-4430-ad8e-430a64e6f6f2
# 21      2023-07-18T20:31:37.323  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 22      2023-07-24T17:54:34.023  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 23      2023-07-26T18:16:47.693  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 24      2024-02-28T23:24:29.323  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 25       2024-10-01T19:12:30.44  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 26       2023-07-06T17:39:03.86  70274950-b208-4db6-9b30-75c74be2bd48
# 27      2023-07-10T17:47:27.277  21468032-c727-4430-ad8e-430a64e6f6f2
# 28      2023-07-10T18:03:37.777  21468032-c727-4430-ad8e-430a64e6f6f2
# 29      2023-08-18T18:54:22.323  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 30      2023-07-24T17:54:45.993  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 31      2023-07-26T18:16:58.403  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
# 32       2024-10-01T19:12:40.99  fc9e80d7-8e6d-47a5-a271-150106fd1e9a
#
#    Creator Principal Display Name Creator Principal Type  \
# 0                    Tommy Puglia                   User
# 1          Learn Fabric Test User                   User
# 2                      Mike Carlo                   User
# 3                      Mike Carlo                   User
# 4                      Mike Carlo                   User
# 5                      Mike Carlo                   User
# 6                    Tommy Puglia                   User
# 7                      Mike Carlo                   User
# 8                      Mike Carlo                   User
# 9                      Mike Carlo                   User
# 10                   Tommy Puglia                   User
# 11         Learn Fabric Test User                   User
# 12                     Mike Carlo                   User
# 13                     Mike Carlo                   User
# 14                     Mike Carlo                   User
# 15                   Tommy Puglia                   User
# 16                     Mike Carlo                   User
# 17                     Mike Carlo                   User
# 18                     Mike Carlo                   User
# 19                   Tommy Puglia                   User
# 20         Learn Fabric Test User                   User
# 21                     Mike Carlo                   User
# 22                     Mike Carlo                   User
# 23                     Mike Carlo                   User
# 24                     Mike Carlo                   User
# 25                     Mike Carlo                   User
# 26                   Tommy Puglia                   User
# 27         Learn Fabric Test User                   User
# 28         Learn Fabric Test User                   User
# 29                     Mike Carlo                   User
# 30                     Mike Carlo                   User
# 31                     Mike Carlo                   User
# 32                     Mike Carlo                   User
#
#    Creator User Principal Name                          Workspace Id  \
# 0         tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 1    learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 2            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 3            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 4            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 5            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 6         tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 7            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 8            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 9            mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 10        tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 11   learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 12           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 13           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 14           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 15        tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 16           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 17           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 18           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 19        tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 20   learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 21           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 22           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 23           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 24           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 25           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 26        tpuglia@pugliabi.com  4498e99d-670c-4d2b-b318-4d8747f21545
# 27   learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 28   learn.fabric@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 29           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 30           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 31           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
# 32           mike@powerbi.tips  4498e99d-670c-4d2b-b318-4d8747f21545
#
#                              Capacity Id
# 0   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 1   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 2   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 3   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 4   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 5   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 6   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 7   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 8   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 9   18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 10  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 11  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 12  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 13  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 14  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 15  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 16  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 17  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 18  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 19  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 20  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 21  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 22  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 23  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 24  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 25  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 26  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 27  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 28  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 29  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 30  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 31  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 32  18fdc1d9-cda4-402a-9e3d-94ef6d83d307

# %% [markdown]
# Lists workspaces for the organization. This function is the admin version of list_workspaces
#
# [admin.list_workspaces](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.admin.html#sempy_labs.admin.list_workspaces)

# %%
labs.admin.list_workspaces()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 52, Finished, Available, Finished)
#                                        Id  Is Read Only  \
# 0    e930318a-b69d-4519-ae4e-c3b952b6e3b5         False
# 1    27f162f1-df6b-4ef2-b72a-fb3cbf0dae7b         False
# 2    2a5addaf-4587-49ad-ab55-654acc7cd668         False
# 3    0cfa7e71-3872-4758-9540-6ef52f580326         False
# 4    61e43dfe-509e-427b-b406-8afffbc95efa         False
# ..                                    ...           ...
# 118  82437270-f1b6-4f6e-918e-9ac26859c574         False
# 119  09552aa0-610c-4619-8ad8-fe5b61c97874         False
# 120  115e87a6-9c98-434f-98f1-f3a8dd838e06         False
# 121  3f6801bb-7279-4e67-abab-78e0bc8dd5af         False
# 122  e5a87865-134b-4c65-b5ee-1cac26b20051         False
#
#      Is On Dedicated Capacity           Type  \
# 0                       False      Workspace
# 1                       False      Workspace
# 2                        True      Workspace
# 3                        True      Workspace
# 4                       False      Workspace
# ..                        ...            ...
# 118                     False  PersonalGroup
# 119                     False  PersonalGroup
# 120                     False  PersonalGroup
# 121                     False  PersonalGroup
# 122                     False  PersonalGroup
#
#                                              Name  \
# 0                     Demo - Google Analytics -HC
# 1                            Demo - SharedDataset
# 2                              Demo - WorkspaceV2
# 3                             Demo - PBI Embedded
# 4                                        COVID-19
# ..                                            ...
# 118              PersonalWorkspace PBI-monitor-05
# 119        PersonalWorkspace PBI-AzureFunction-01
# 120       PersonalWorkspace DevEmbeddedPowerBI-02
# 121             PersonalWorkspace Dev - Workloads
# 122  PersonalWorkspace Test - PBI Monitor Reports
#
#                               Capacity Id Default Dataset Storage Format  \
# 0                                    None                           None
# 1                                    None                           None
# 2    2c60ca79-d408-47a4-ace8-8a3feb9e6bf4                          Small
# 3    18fdc1d9-cda4-402a-9e3d-94ef6d83d307                          Small
# 4                                    None                           None
# ..                                    ...                            ...
# 118                                  None                           None
# 119                                  None                           None
# 120                                  None                           None
# 121                                  None                           None
# 122                                  None                           None
#
#     Pipeline Id  Has Workspace Level Settings   State
# 0          None                         False  Active
# 1          None                         False  Active
# 2          None                         False  Active
# 3          None                         False  Active
# 4          None                         False  Active
# ..          ...                           ...     ...
# 118        None                         False  Active
# 119        None                         False  Active
# 120        None                         False  Active
# 121        None                         False  Active
# 122        None                         False  Active
#
# [123 rows x 10 columns]

# %%
df = labs.admin.list_workspaces()
display(df)
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 55, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 898d0c35-603c-4c16-8b9c-ec6fafc453f4)

# %% [markdown]
# ## Lakehouse

# %%
labs.list_lakehouses()
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 58, Finished, Available, Finished)
#    Lakehouse Name                          Lakehouse ID Description  \
# 0  TheGreatLake02  12481425-eadd-4f82-8a29-ea9bf7762e95
# 1      OData_Lake  897ddf45-e498-47a9-8441-1f5febed4fed
# 2    SampleSchema  abea0664-a908-484a-a636-5ce3b0647a0f
# 3    Contoso_100K  9b7f9863-9f70-4630-bb66-7b078e7d9ff4
#
#                                  OneLake Tables Path  \
# 0  https://onelake.dfs.fabric.microsoft.com/7954c...
# 1  https://onelake.dfs.fabric.microsoft.com/7954c...
# 2  https://onelake.dfs.fabric.microsoft.com/7954c...
# 3  https://onelake.dfs.fabric.microsoft.com/7954c...
#
#                                   OneLake Files Path  \
# 0  https://onelake.dfs.fabric.microsoft.com/7954c...
# 1  https://onelake.dfs.fabric.microsoft.com/7954c...
# 2  https://onelake.dfs.fabric.microsoft.com/7954c...
# 3  https://onelake.dfs.fabric.microsoft.com/7954c...
#
#                       SQL Endpoint Connection String  \
# 0  vjnui4spggjeze3edszmjesl6y-b3evi6mony5e7i2ktff...
# 1  vjnui4spggjeze3edszmjesl6y-b3evi6mony5e7i2ktff...
# 2  vjnui4spggjeze3edszmjesl6y-b3evi6mony5e7i2ktff...
# 3  vjnui4spggjeze3edszmjesl6y-b3evi6mony5e7i2ktff...
#
#                         SQL Endpoint ID SQL Endpoint Provisioning Status
# 0  445b9119-09a5-46e6-a03e-4b1678c291c9                          Success
# 1  3b7c26c5-8bc5-4e69-add7-9cb6bd5fb01b                          Success
# 2  276e0f7b-6adb-4dae-bdfc-1786a0763fa9                          Success
# 3  88948de1-dd49-4578-bc33-e4ae1661fd97                          Success

# %%
labs.lakehouse.get_lakehouse_tables('Contoso_100K')

# does not work with lakehouses that have an enabled schema
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 62, Finished, Available, Finished)
#              Workspace Name Lakehouse Name        Table Name Format     Type  \
# 0  Demo - Learn Fabric - 02   Contoso_100K  currencyexchange  delta  Managed
# 1  Demo - Learn Fabric - 02   Contoso_100K          customer  delta  Managed
# 2  Demo - Learn Fabric - 02   Contoso_100K     customersport  delta  Managed
# 3  Demo - Learn Fabric - 02   Contoso_100K              date  delta  Managed
# 4  Demo - Learn Fabric - 02   Contoso_100K           product  delta  Managed
# 5  Demo - Learn Fabric - 02   Contoso_100K             sales  delta  Managed
# 6  Demo - Learn Fabric - 02   Contoso_100K             sport  delta  Managed
# 7  Demo - Learn Fabric - 02   Contoso_100K             store  delta  Managed
#
#                                             Location
# 0  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 1  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 2  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 3  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 4  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 5  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 6  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...
# 7  abfss://7954c90e-6e8e-4f3a-a34a-994b9d1c66c8@o...

# %% [markdown]
# Other helpful lakehouse commands
# - [lakehouse.optimize_lakehouse_tables](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.lakehouse.html#sempy_labs.lakehouse.optimize_lakehouse_tables)
# - [lakehouse.vacuum_lakehouse](https://semantic-link-labs.readthedocs.io/en/latest/sempy_labs.lakehouse.html#sempy_labs.lakehouse.optimize_lakehouse_tables)

# %% [markdown]
# ## TOM (Tabular Object Model)

# %%
# List all items in a workspace
items = labs.admin.list_items(workspace='Demo - Learn Fabric')

# Filter and display list of items that are only models
items[items['Type'] == 'SemanticModel']
# Out:
# StatementMeta(, 9ca522e2-e66a-4315-8db9-63d808b8539c, 71, Finished, Available, Finished)
#                                  Item Id                   Item Name  \
# 19  62320506-bd9b-4c66-a7aa-8bb8f324b546                TheGreatLake
# 20  0eb91f22-f726-40e1-b3e5-21f0018926bb  DataflowsStagingLakehouse1
# 21  fb90dd56-639e-4da8-9eb9-04125b74ba07             Batting Dataset
# 22  030e8e56-3d5e-4c6a-824d-042293d340cd          WorldWideImporters
# 23  2e76574a-4e24-47a6-af2b-6687c64c43f6                    NYC_Taxi
# 24  2582cd67-8ad9-4110-b177-b0e0d4e6cfe7                 Taxi Data 2
# 25  c13bb7d4-66a0-4d0b-8df5-81f089687b82                   ShortCuts
#
#              Type Description   State        Last Updated Date  \
# 19  SemanticModel        None  Active  2023-07-06T17:38:54.017
# 20  SemanticModel        None  Active  2023-07-10T17:47:15.667
# 21  SemanticModel        None  Active  2023-07-18T20:31:37.323
# 22  SemanticModel        None  Active  2023-07-24T17:54:34.023
# 23  SemanticModel        None  Active  2023-07-26T18:16:47.693
# 24  SemanticModel        None  Active  2024-02-28T23:24:29.323
# 25  SemanticModel        None  Active   2024-10-01T19:12:30.44
#
#                     Creator Principal Id Creator Principal Display Name  \
# 19  70274950-b208-4db6-9b30-75c74be2bd48                   Tommy Puglia
# 20  21468032-c727-4430-ad8e-430a64e6f6f2         Learn Fabric Test User
# 21  fc9e80d7-8e6d-47a5-a271-150106fd1e9a                     Mike Carlo
# 22  fc9e80d7-8e6d-47a5-a271-150106fd1e9a                     Mike Carlo
# 23  fc9e80d7-8e6d-47a5-a271-150106fd1e9a                     Mike Carlo
# 24  fc9e80d7-8e6d-47a5-a271-150106fd1e9a                     Mike Carlo
# 25  fc9e80d7-8e6d-47a5-a271-150106fd1e9a                     Mike Carlo
#
#    Creator Principal Type Creator User Principal Name  \
# 19                   User        tpuglia@pugliabi.com
# 20                   User   learn.fabric@powerbi.tips
# 21                   User           mike@powerbi.tips
# 22                   User           mike@powerbi.tips
# 23                   User           mike@powerbi.tips
# 24                   User           mike@powerbi.tips
# 25                   User           mike@powerbi.tips
#
#                             Workspace Id                           Capacity Id
# 19  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 20  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 21  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 22  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 23  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 24  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307
# 25  4498e99d-670c-4d2b-b318-4d8747f21545  18fdc1d9-cda4-402a-9e3d-94ef6d83d307

# %%
with labs.tom.connect_semantic_model(workspace='Demo - Learn Fabric',dataset='Batting Dataset',readonly=True) as tom:
    for t in tom.model.Tables:
        print(t.Name)
# Out:
# StatementMeta(, 993971ea-1635-409b-bbf1-489dd1e2ef47, 12, Finished, Available, Finished)
# People_01
# Batting_01
